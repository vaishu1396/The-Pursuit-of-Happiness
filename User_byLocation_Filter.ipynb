# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importing libraries
import os
import sys
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Twitter/user_combined.csv')
print(df.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2,26,27,28,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                            _type         username                 userId  \
# 0  snscrape.modules.twitter.User        Danno2430               40591067
# 1  snscrape.modules.twitter.User  SharrodSharrod7              479760616
# 2  snscrape.modules.twitter.User        JPBGerald               23435297
# 3  snscrape.modules.twitter.User     SydTheJackal  1.21032249306563E+018
# 4  snscrape.modules.twitter.User           __paix             3215771949
#
#                         displayname  \
# 0  Kreidbanejad Publicity Tour 2022
# 1                  Sharrod Williams
# 2                        JPB Gerald
# 3        Sydney “THE JACKAL” Maccow
# 4                    Isnery Marrero
#
#                                       rawDescription  \
# ...

# %%
df.dtypes
# Out:
# _type                    object
# username                 object
# userId                   object
# displayname              object
# rawDescription           object
# descriptionUrls          object
# verified                 object
# created                  object
# followersCount           object
# friendsCount             object
# statusesCount            object
# favouritesCount          object
# listedCount              object
# mediaCount               object
# location                 object
# protected                object
# linkUrl                  object
# profileImageUrl          object
# profileBannerUrl         object
# label                    object
# profileUrl               object
# label._type              object
# label.description        object
# label.url                object
# label.badgeUrl           object
# label.longDescription    object
# Unnamed: 26              object
# Unnamed: 27              object
# Unnamed: 28              object
# ...

# %%
df.drop(['_type','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30'], axis=1, inplace=True)

# %%
df.drop(['linkUrl','profileImageUrl','profileBannerUrl','label','profileUrl','label._type'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# username                 object
# userId                   object
# displayname              object
# rawDescription           object
# descriptionUrls          object
# verified                 object
# created                  object
# followersCount           object
# friendsCount             object
# statusesCount            object
# favouritesCount          object
# listedCount              object
# mediaCount               object
# location                 object
# protected                object
# label.description        object
# label.url                object
# label.badgeUrl           object
# label.longDescription    object
# dtype: object

# %%
df.drop(df.columns[5:10], axis = 1, inplace = True)

# %%
df.head()
# Out:
#           username                 userId                       displayname  \
# 0        Danno2430               40591067  Kreidbanejad Publicity Tour 2022
# 1  SharrodSharrod7              479760616                  Sharrod Williams
# 2        JPBGerald               23435297                        JPB Gerald
# 3     SydTheJackal  1.21032249306563E+018        Sydney “THE JACKAL” Maccow
# 4           __paix             3215771949                    Isnery Marrero
#
#                                       rawDescription  \
# 0                                        “They'd say
# 1  📍NYC | 🎬 EP, Writer, Creator @NeighborsSeries ...
# 2  He/him.\nBlack/ADHD EdD candidate @ Hunter.\nP...
# 3  https://t.co/woBagB2QjZ | Boxing Coach | Fitne...
# 4                                       | ΧΥΣ | KA |
#
#                                      descriptionUrls favouritesCount  \
# 0   'no sloppy steaks' but they can't stop you fr...          379224
# ...

# %%
df.shape
# Out:
# (242121, 14)

# %%
df.drop_duplicates(subset=['userId'], inplace=True)

# %%
df.shape
# Out:
# (133500, 14)

# %%
df_loc = df.dropna(subset=['location'])

# %%
df_loc.drop(df_loc.columns[9:], axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_loc.shape
# Out:
# (112723, 9)

# %%
df_loc.head()
# Out:
#           username                 userId                       displayname  \
# 0        Danno2430               40591067  Kreidbanejad Publicity Tour 2022
# 1  SharrodSharrod7              479760616                  Sharrod Williams
# 2        JPBGerald               23435297                        JPB Gerald
# 3     SydTheJackal  1.21032249306563E+018        Sydney “THE JACKAL” Maccow
# 5     SnipedPaulie  1.18237453417289E+018                    Hood Favorite🗽
#
#                                       rawDescription  \
# 0                                        “They'd say
# 1  📍NYC | 🎬 EP, Writer, Creator @NeighborsSeries ...
# 2  He/him.\nBlack/ADHD EdD candidate @ Hunter.\nP...
# 3  https://t.co/woBagB2QjZ | Boxing Coach | Fitne...
# 5  NYC | 25 🇭🇹🇨🇺 BO4 Stan Account. Half gangsta H...
#
#                                      descriptionUrls favouritesCount  \
# 0   'no sloppy steaks' but they can't stop you fr...          379224
# ...

# %%
df_loc['location'] = df_loc['location'].str.upper()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_loc
# Out:
#                username                 userId  \
# 0             Danno2430               40591067
# 1       SharrodSharrod7              479760616
# 2             JPBGerald               23435297
# 3          SydTheJackal  1.21032249306563E+018
# 5          SnipedPaulie  1.18237453417289E+018
# ...                 ...                    ...
# 242112   karenmaywrites             31633527.0
# 242116   rahmathadi_ben            120507505.0
# 242117        ChadMac19            634170042.0
# 242119   camcrewstudios  1374392682882109952.0
# 242120   Marco_Angelo15            416349230.0
#
#                              displayname  \
# 0       Kreidbanejad Publicity Tour 2022
# 1                       Sharrod Williams
# 2                             JPB Gerald
# 3             Sydney “THE JACKAL” Maccow
# 5                         Hood Favorite🗽
# ...                                  ...
# 242112                    karen bolipata
# 242116                       Rahmat Hadi
# ...

# %%
contain_location = df_loc[df_loc['location'].str.contains('NY|NEW YORK|MANHATTAN|BROOKLYN|QUEENS|BRONX|STATEN ISLAND')]

# %%
contain_location.head()
# Out:
#           username                 userId                 displayname  \
# 1  SharrodSharrod7              479760616            Sharrod Williams
# 2        JPBGerald               23435297                  JPB Gerald
# 3     SydTheJackal  1.21032249306563E+018  Sydney “THE JACKAL” Maccow
# 6            511NY               50706690                511 New York
# 7         azu_musa              465220100                  Azu Olvera
#
#                                       rawDescription  \
# 1  📍NYC | 🎬 EP, Writer, Creator @NeighborsSeries ...
# 2  He/him.\nBlack/ADHD EdD candidate @ Hunter.\nP...
# 3  https://t.co/woBagB2QjZ | Boxing Coach | Fitne...
# 6  Traffic & transit updates for all of New York ...
# 7  música •Head of Latin Talent & Industry Relati...
#
#                                      descriptionUrls favouritesCount  \
# 1                                                NaN            9492
# 2                                                NaN           45612
# ...

# %%
contain_location.shape
# Out:
# (63055, 9)

# %%
user_loc_file = "UsersNY.csv"

# %%
from google.colab import files

# %%
contain_location.to_csv(user_loc_file, index=None)
files.download(user_loc_file)

# %%
#import pandas as pd
#import numpy as np
#df1 = pd.DataFrame({'A': 'foo bar foo bar foo bar foo foo'.split(),
#                   'B': 'one one two three two two one three'.split(),
#                   'C': np.arange(8), 'D': np.arange(8) * 2})
#print(df1)
# Out:
#      A      B  C   D
# 0  foo    one  0   0
# 1  bar    one  1   2
# 2  foo    two  2   4
# 3  bar  three  3   6
# 4  foo    two  4   8
# 5  bar    two  5  10
# 6  foo    one  6  12
# 7  foo  three  7  14

# %%
#df2 = pd.DataFrame({'A': 'foo bar'.split(),
#                   'B': 'one two'.split()
#                   })
#print(df2)
# Out:
#      A    B
# 0  foo  one
# 1  bar  two

# %%
#df = df1.merge(df2, on=['B'])
#print(df)
# Out:
#    A_x    B  C   D  A_y
# 0  foo  one  0   0  foo
# 1  bar  one  1   2  foo
# 2  foo  one  6  12  foo
# 3  foo  two  2   4  bar
# 4  foo  two  4   8  bar
# 5  bar  two  5  10  bar

# %%
#df_new = df1.loc[df1['B'].isin(df2['B'])]
#df_new
# Out:
#      A    B  C   D
# 0  foo  one  0   0
# 1  bar  one  1   2
# 2  foo  two  2   4
# 4  foo  two  4   8
# 5  bar  two  5  10
# 6  foo  one  6  12

# %%
#final_locat = {'NY', 'NEW YORK', 'BROOKLYN', 'MANHATTAN', 'BRONX','QUEENS','STATEN ISLAND'}

# %%
#df_floc = df_loc.loc[df_loc['location'].isin(final_locat)]

# %%
#df_floc.head()
# Out:
#           username     userId        displayname  \
# 33      badgaIsabs  539407414        sadgalsabs*
# 45    audreyvnoble  182047998       Audrey Noble
# 75  LoveTheLudwigs   16387116  Love, the Ludwigs
# 84         GENN4DY   21447873     Gennady Kolker
# 95      EtherealNY   63597186         Zee Oz NYC
#
#                                        rawDescription  \
# 33                          unfriendly blasian hottie
# 45  👩🏻‍💻 Beauty writer @bustle. Freelance @wwd @al...
# 75  Our family of 4 + 2 dogs lives in Rockland Cou...
# 84  Director, Programming @BleacherReport. Former ...
# 95  https://t.co/bwvILsVZNw\n\nhttps://t.co/z8qDQm...
#
#                                       descriptionUrls favouritesCount  \
# 33                                                NaN           55743
# 45                                                NaN           46456
# 75                                                NaN            2055
# ...

# %%
#df_floc.shape
# Out:
# (4876, 9)
